# %% [markdown]
# # 2층 신경망 역전파 유도
#
# 구조: 입력 2개 -> 은닉 2개 -> 출력 1개

# %% [markdown]
# ## 1. 고정 예제와 Shape
#
# - x: (2,) = [1, 0]
# - W1: (2, 2) = [[0.1, 0.2], [0.3, 0.4]]
# - b1: (2,) = [0, 0]
# - W2: (2,) = [0.5, 0.6]
# - b2: scalar = 0
# - y_true: scalar = 1
# - activation: sigmoid
# - loss: Binary Cross-Entropy

# %% [markdown]
# ## 2. 순전파 손계산
#
# TODO: z1, a1, z2, y_pred를 단계별로 계산하고 shape을 표기한다.

# %% [markdown]
# ## 3. 역전파 수식 유도
#
# TODO: dL/dy_pred, dL/dz2, dL/dW2, dL/da1, dL/dz1, dL/dW1을 연쇄 법칙으로 유도한다.

# %%
import numpy as np

np.random.seed(42)

# TODO: 손계산 결과와 NumPy 계산 결과가 소수점 4자리까지 일치하는지 검증한다.
